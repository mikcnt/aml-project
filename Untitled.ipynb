# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import *
from data_loader import GrayscaleImageFolder
from torchvision import transforms
from skimage.transform import resize
from model import *
import warnings
from PIL import Image
warnings.filterwarnings("ignore")

batch_size = 4
# Out:
#   File "<ipython-input-1-b838bb23cf95>", line 10
#     from sklearn
#                  ^
# SyntaxError: invalid syntax

# %%
train_transforms = transforms.Compose([transforms.Resize((224, 224))])
train_imagefolder = GrayscaleImageFolder('data/train', transform=train_transforms)
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=1, shuffle=True)
iterator = iter(train_loader)

# %%
# resuming model
checkpoint = torch.load('checkpoints/best-model.pth')
model = ColorizationNet()
model.load_state_dict(checkpoint)
# Out:
# <All keys matched successfully>

# %%
img = np.array(Image.open('data/train/fruits/orange_2.jpg'))
img_lab = rgb2lab(img)
img_gray = img_lab[:, :, 0] / 100
img_gray_tensor = torch.from_numpy(resize(img_gray, (224, 224))).unsqueeze(0).float()
img_gray_tensor.shape
# Out:
# torch.Size([1, 224, 224])

# %%
img_gray_batch = img_gray_tensor.unsqueeze(0)
img_smooth = model(img_gray_batch)[0]

# %%
img_prediction = gray_smooth_tensor2rgb(img_gray_tensor, img_smooth.detach())

# %%
plt.imshow(img_prediction)
